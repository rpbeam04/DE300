# %% [markdown]
# # Apache Airflow Tutorial
# ⚠️ Cost-Saving Note
# Amazon MWAA can be expensive to run. To minimize cost, please form a temporary group of two or more students (this group may differ from your homework group).
#
# ## Setting Up Airflow on AWS (Amazon MWAA)
# 0. Create an S3 bucket
#
#     - Go to the AWS Management Console and ensure your region is set to N. Virginia.
#
#     - Create a new bucket named Lastname1-Lastname2-Bucket (replace with actual last names).
#
#     - Leave all other settings as default.
#
#     - After the bucket is created, create a folder named dags inside it.
#
# 1. Open Amazon MWAA
#
#     - In the AWS Console search bar, type Amazon MWAA and navigate to the service.
#
#     - Make sure the region is N. Virginia, then click "Create environment".
#
# 2. Configure the environment
#
#     - Set the environment name to Lastname1-Lastname2-MWAA.
#
#     - Select the latest Airflow version available.
#
# 3. Configure storage
#
#     - For the S3 bucket, choose the one you just created.
#
#     - Set the DAGs folder to the dags folder you created inside that bucket.
#
# 4. Configure networking
#
#     - For VPC, select MWAA-VPC-DE300.
#
#     - For Web server access, choose Public.
#
# 5. Launch the environment
#
#     - Scroll to the bottom of the page and click "Create environment".
#
#     - It will take approximately 20–30 minutes for the environment to become active.
#
# ## Introduction
# Apache Airflow is an open-source workflow orchestration tool that allows users to define, schedule, and monitor workflows as Directed Acyclic Graphs (DAGs). It is widely used for automating ETL (Extract, Transform, Load) processes, data pipelines, and machine learning workflows.
#
# This tutorial will guide you through the installation, basic concepts, and workflow creation using Airflow.
#
# ## Installation
# Before installing Airflow, ensure you have the latest version pip. You can upgrade it by
# ```
# python -m pip install --upgrade pip
# ```
# The we can install Airflow by
# ```
# pip install apache-airflow
# ```
# In the examples in the lab session today, we may also need the following 2 dependencies:
# ```
# pip install apache-airflow-providers-sftp
#     - [ ] pip install apache-airflow-providers-postgres
# ```

# %%
# !pip install apache-airflow
# Out:
# Collecting apache-airflow
#   Downloading apache_airflow-3.0.1-py3-none-any.whl.metadata (32 kB)
# Collecting apache-airflow-core==3.0.1 (from apache-airflow)
#   Downloading apache_airflow_core-3.0.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting apache-airflow-task-sdk<1.1.0,>=1.0.0 (from apache-airflow)
#   Downloading apache_airflow_task_sdk-1.0.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting a2wsgi>=1.10.8 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading a2wsgi-1.10.8-py3-none-any.whl.metadata (3.9 kB)
# Collecting aiosqlite>=0.20.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting alembic<2.0,>=1.13.1 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting apache-airflow-providers-common-compat>=1.6.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading apache_airflow_providers_common_compat-1.7.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting apache-airflow-providers-common-io>=1.5.3 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading apache_airflow_providers_common_io-1.6.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting apache-airflow-providers-common-sql>=1.26.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading apache_airflow_providers_common_sql-1.27.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting apache-airflow-providers-smtp>=2.0.2 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading apache_airflow_providers_smtp-2.1.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting apache-airflow-providers-standard>=0.4.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading apache_airflow_providers_standard-1.2.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting argcomplete>=1.10 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading argcomplete-3.6.2-py3-none-any.whl.metadata (16 kB)
# Collecting asgiref>=2.3.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: attrs!=25.2.0,>=22.1.0 in /opt/conda/lib/python3.11/site-packages (from apache-airflow-core==3.0.1->apache-airflow) (23.1.0)
# Collecting cadwyn>=5.2.1 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading cadwyn-5.3.3-py3-none-any.whl.metadata (4.5 kB)
# Collecting colorlog>=6.8.2 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting cron-descriptor>=1.2.24 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading cron_descriptor-1.4.5-py3-none-any.whl.metadata (5.7 kB)
# Collecting croniter>=2.0.2 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading croniter-6.0.0-py2.py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: cryptography>=41.0.0 in /opt/conda/lib/python3.11/site-packages (from apache-airflow-core==3.0.1->apache-airflow) (41.0.4)
# Collecting deprecated>=1.2.13 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: dill>=0.2.2 in /opt/conda/lib/python3.11/site-packages (from apache-airflow-core==3.0.1->apache-airflow) (0.3.7)
# Collecting fastapi!=0.115.10,>=0.115.0 (from fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting flask>=2.1.1 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading flask-3.1.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting gunicorn>=20.1.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting httpx>=0.25.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: importlib-metadata>=6.5 in /opt/conda/lib/python3.11/site-packages (from apache-airflow-core==3.0.1->apache-airflow) (6.8.0)
# Collecting itsdangerous>=2.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jinja2>=3.1.5 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: jsonschema>=4.19.1 in /opt/conda/lib/python3.11/site-packages (from apache-airflow-core==3.0.1->apache-airflow) (4.19.1)
# Collecting lazy-object-proxy>=1.2.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading lazy_object_proxy-1.11.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting libcst>=1.1.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading libcst-1.8.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting linkify-it-py>=2.0.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting lockfile>=0.12.2 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting methodtools>=0.4.7 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading methodtools-0.4.7-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting opentelemetry-api>=1.26.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading opentelemetry_api-1.33.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-exporter-otlp>=1.26.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading opentelemetry_exporter_otlp-1.33.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: packaging>=23.2 in /opt/conda/lib/python3.11/site-packages (from apache-airflow-core==3.0.1->apache-airflow) (23.2)
# Collecting pathspec>=0.9.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Collecting pendulum<4.0,>=2.1.2 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading pendulum-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting pluggy>=1.5.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.11/site-packages (from apache-airflow-core==3.0.1->apache-airflow) (5.9.5)
# Collecting pydantic>=2.11.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading pydantic-2.11.5-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: pygments!=2.19.0,>=2.0.1 in /opt/conda/lib/python3.11/site-packages (from apache-airflow-core==3.0.1->apache-airflow) (2.16.1)
# Collecting pyjwt>=2.10.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting python-daemon>=3.0.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading python_daemon-3.1.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in /opt/conda/lib/python3.11/site-packages (from apache-airflow-core==3.0.1->apache-airflow) (2.8.2)
# Collecting python-slugify>=5.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests<3,>=2.31.0 in /opt/conda/lib/python3.11/site-packages (from apache-airflow-core==3.0.1->apache-airflow) (2.31.0)
# Collecting rich-argparse>=1.0.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading rich_argparse-1.7.1-py3-none-any.whl.metadata (14 kB)
# Collecting rich>=13.6.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting setproctitle>=1.3.3 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading setproctitle-1.3.6-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting sqlalchemy-jsonfield>=1.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading SQLAlchemy_JSONField-1.0.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting sqlalchemy-utils>=0.41.2 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading SQLAlchemy_Utils-0.41.2-py3-none-any.whl.metadata (4.2 kB)
# Collecting sqlalchemy<2.0,>=1.4.49 (from sqlalchemy[asyncio]<2.0,>=1.4.49->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading SQLAlchemy-1.4.54-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting svcs>=25.1.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading svcs-25.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting tabulate>=0.9.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting tenacity!=8.2.0,>=8.0.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting termcolor>=3.0.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting universal-pathlib!=0.2.4,>=0.2.2 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading universal_pathlib-0.2.6-py3-none-any.whl.metadata (25 kB)
# Collecting uuid6>=2024.7.10 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading uuid6-2024.7.10-py3-none-any.whl.metadata (8.6 kB)
# Collecting aiologic>=0.14.0 (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow)
#   Downloading aiologic-0.14.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting attrs!=25.2.0,>=22.1.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting fsspec>=2023.10.0 (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow)
#   Downloading fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Collecting msgspec>=0.19.0 (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow)
#   Downloading msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting psutil>=5.8.0 (from apache-airflow-core==3.0.1->apache-airflow)
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting retryhttp!=1.3.0,>=1.2.0 (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow)
#   Downloading retryhttp-1.3.3-py3-none-any.whl.metadata (17 kB)
# Collecting structlog>=25.2.0 (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow)
#   Downloading structlog-25.3.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting wrapt>=1.16.0 (from aiologic>=0.14.0->apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow)
#   Downloading wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: typing_extensions>=4.0 in /opt/conda/lib/python3.11/site-packages (from aiosqlite>=0.20.0->apache-airflow-core==3.0.1->apache-airflow) (4.8.0)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.11/site-packages (from alembic<2.0,>=1.13.1->apache-airflow-core==3.0.1->apache-airflow) (1.2.4)
# Collecting typing_extensions>=4.0 (from aiosqlite>=0.20.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting sqlparse>=0.5.1 (from apache-airflow-providers-common-sql>=1.26.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting more-itertools>=9.0.0 (from apache-airflow-providers-common-sql>=1.26.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading more_itertools-10.7.0-py3-none-any.whl.metadata (37 kB)
# Collecting starlette>=0.30.0 (from cadwyn>=5.2.1->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading starlette-0.47.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pytz>2021.1 in /opt/conda/lib/python3.11/site-packages (from croniter>=2.0.2->apache-airflow-core==3.0.1->apache-airflow) (2023.3.post1)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.11/site-packages (from cryptography>=41.0.0->apache-airflow-core==3.0.1->apache-airflow) (1.16.0)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting fastapi-cli>=0.0.5 (from fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading fastapi_cli-0.0.7-py3-none-any.whl.metadata (6.2 kB)
# Collecting python-multipart>=0.0.18 (from fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting email-validator>=2.0.0 (from fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting uvicorn>=0.12.0 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Collecting blinker>=1.9.0 (from flask>=2.1.1->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.11/site-packages (from flask>=2.1.1->apache-airflow-core==3.0.1->apache-airflow) (8.1.7)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from flask>=2.1.1->apache-airflow-core==3.0.1->apache-airflow) (2.1.3)
# Collecting werkzeug>=3.1.0 (from flask>=2.1.1->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.11/site-packages (from httpx>=0.25.0->apache-airflow-core==3.0.1->apache-airflow) (4.0.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx>=0.25.0->apache-airflow-core==3.0.1->apache-airflow) (2023.7.22)
# Collecting httpcore==1.* (from httpx>=0.25.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx>=0.25.0->apache-airflow-core==3.0.1->apache-airflow) (3.4)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata>=6.5->apache-airflow-core==3.0.1->apache-airflow) (3.17.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.19.1->apache-airflow-core==3.0.1->apache-airflow) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.19.1->apache-airflow-core==3.0.1->apache-airflow) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.19.1->apache-airflow-core==3.0.1->apache-airflow) (0.10.6)
# Requirement already satisfied: pyyaml>=5.2 in /opt/conda/lib/python3.11/site-packages (from libcst>=1.1.0->apache-airflow-core==3.0.1->apache-airflow) (6.0.1)
# Collecting uc-micro-py (from linkify-it-py>=2.0.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting wirerope>=0.4.7 (from methodtools>=0.4.7->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading wirerope-1.0.0-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.33.1 (from opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.33.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.33.1 (from opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.33.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting grpcio<2.0.0,>=1.63.2 (from opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading grpcio-1.71.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.33.1 (from opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.33.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.33.1 (from opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading opentelemetry_proto-1.33.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk~=1.33.1 (from opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading opentelemetry_sdk-1.33.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting protobuf<6.0,>=5.0 (from opentelemetry-proto==1.33.1->opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: tzdata>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pendulum<4.0,>=2.1.2->apache-airflow-core==3.0.1->apache-airflow) (2023.3)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.11.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic>=2.11.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic>=2.11.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7.0->apache-airflow-core==3.0.1->apache-airflow) (1.16.0)
# Collecting text-unidecode>=1.3 (from python-slugify>=5.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.31.0->apache-airflow-core==3.0.1->apache-airflow) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.31.0->apache-airflow-core==3.0.1->apache-airflow) (2.0.7)
# Collecting types-requests (from retryhttp!=1.3.0,>=1.2.0->apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow)
#   Downloading types_requests-2.32.0.20250515-py3-none-any.whl.metadata (2.1 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.6.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy<2.0,>=1.4.49->sqlalchemy[asyncio]<2.0,>=1.4.49->apache-airflow-core==3.0.1->apache-airflow) (3.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=41.0.0->apache-airflow-core==3.0.1->apache-airflow) (2.21)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting typer>=0.12.3 (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Collecting rich-toolkit>=0.11.1 (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading rich_toolkit-0.14.7-py3-none-any.whl.metadata (999 bytes)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.6.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.11/site-packages (from anyio->httpx>=0.25.0->apache-airflow-core==3.0.1->apache-airflow) (1.3.0)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading websockets-15.0.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting opentelemetry-semantic-conventions==0.54b1 (from opentelemetry-sdk~=1.33.1->opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp>=1.26.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading opentelemetry_semantic_conventions-0.54b1-py3-none-any.whl.metadata (2.5 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.12.3->fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.1->apache-airflow)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Downloading apache_airflow-3.0.1-py3-none-any.whl (12 kB)
# Downloading apache_airflow_core-3.0.1-py3-none-any.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 47.6 MB/s eta 0:00:0000:0100:01
# Downloading apache_airflow_task_sdk-1.0.1-py3-none-any.whl (234 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.3/234.3 kB 14.9 MB/s eta 0:00:00
# Downloading a2wsgi-1.10.8-py3-none-any.whl (17 kB)
# Downloading aiologic-0.14.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 2.5 MB/s eta 0:00:00
# Downloading aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 17.6 MB/s eta 0:00:00
# Downloading apache_airflow_providers_common_compat-1.7.0-py3-none-any.whl (30 kB)
# Downloading apache_airflow_providers_common_io-1.6.0-py3-none-any.whl (19 kB)
# Downloading apache_airflow_providers_common_sql-1.27.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 5.5 MB/s eta 0:00:00
# Downloading apache_airflow_providers_smtp-2.1.0-py3-none-any.whl (21 kB)
# Downloading apache_airflow_providers_standard-1.2.0-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.7/103.7 kB 9.5 MB/s eta 0:00:00
# Downloading argcomplete-3.6.2-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.2 MB/s eta 0:00:00
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 5.5 MB/s eta 0:00:00
# Downloading cadwyn-5.3.3-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 4.9 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading cron_descriptor-1.4.5-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 4.3 MB/s eta 0:00:00
# Downloading croniter-6.0.0-py2.py3-none-any.whl (25 kB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 8.2 MB/s eta 0:00:00
# Downloading flask-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 7.2 MB/s eta 0:00:00
# Downloading fsspec-2025.5.1-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 16.6 MB/s eta 0:00:00
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 8.0 MB/s eta 0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 6.6 MB/s eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 7.0 MB/s eta 0:00:00
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 10.6 MB/s eta 0:00:00
# Downloading lazy_object_proxy-1.11.0-py3-none-any.whl (16 kB)
# Downloading libcst-1.8.0-cp311-cp311-manylinux_2_28_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 43.5 MB/s eta 0:00:00a 0:00:01
# Downloading linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Downloading methodtools-0.4.7-py2.py3-none-any.whl (4.0 kB)
# Downloading msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 16.4 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.33.1-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 6.3 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp-1.33.1-py3-none-any.whl (7.0 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.33.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_http-1.33.1-py3-none-any.whl (17 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.33.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.33.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 4.7 MB/s eta 0:00:00
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading pendulum-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (353 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.7/353.7 kB 23.1 MB/s eta 0:00:00
# Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 21.2 MB/s eta 0:00:00
# Downloading pydantic-2.11.5-py3-none-any.whl (444 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.2/444.2 kB 30.8 MB/s eta 0:00:00
# Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 56.1 MB/s eta 0:00:0000:01
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading python_daemon-3.1.2-py3-none-any.whl (30 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading retryhttp-1.3.3-py3-none-any.whl (17 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.2/243.2 kB 21.3 MB/s eta 0:00:00
# Downloading rich_argparse-1.7.1-py3-none-any.whl (25 kB)
# Downloading setproctitle-1.3.6-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Downloading SQLAlchemy-1.4.54-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.5 MB/s eta 0:00:00
# Downloading SQLAlchemy_JSONField-1.0.2-py3-none-any.whl (10 kB)
# Downloading SQLAlchemy_Utils-0.41.2-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 8.3 MB/s eta 0:00:00
# Downloading structlog-25.3.0-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.2/68.2 kB 6.7 MB/s eta 0:00:00
# Downloading svcs-25.1.0-py3-none-any.whl (19 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading universal_pathlib-0.2.6-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 4.8 MB/s eta 0:00:00
# Downloading uuid6-2024.7.10-py3-none-any.whl (6.4 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading fastapi_cli-0.0.7-py3-none-any.whl (10 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 7.2 MB/s eta 0:00:00
# Downloading more_itertools-10.7.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 kB 6.6 MB/s eta 0:00:00
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.9 MB/s eta 0:00:00
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.4 MB/s eta 0:00:00
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 6.7 MB/s eta 0:00:00
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.6 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.6 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 19.5 MB/s eta 0:00:00
# Downloading wirerope-1.0.0-py2.py3-none-any.whl (9.2 kB)
# Downloading wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 8.2 MB/s eta 0:00:00
# Downloading types_requests-2.32.0.20250515-py3-none-any.whl (20 kB)
# Downloading uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 23.4 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.5/294.5 kB 22.3 MB/s eta 0:00:00
# Downloading grpcio-1.71.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 62.2 MB/s eta 0:00:0000:0100:01
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 30.1 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading opentelemetry_sdk-1.33.1-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 10.0 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.54b1-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.9/194.9 kB 15.5 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading rich_toolkit-0.14.7-py3-none-any.whl (24 kB)
# Downloading typer-0.16.0-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 3.9 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 74.7 MB/s eta 0:00:00ta 0:00:01
# Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (454 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 36.0 MB/s eta 0:00:00
# Downloading websockets-15.0.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 18.7 MB/s eta 0:00:00
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.9/319.9 kB 26.6 MB/s eta 0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: text-unidecode, lockfile, cron-descriptor, wrapt, wirerope, werkzeug, websockets, uvloop, uuid6, uc-micro-py, typing_extensions, types-requests, termcolor, tenacity, tabulate, structlog, sqlparse, sqlalchemy, shellingham, setproctitle, python-slugify, python-multipart, python-dotenv, python-daemon, pyjwt, psutil, protobuf, pluggy, pathspec, msgspec, more-itertools, mdurl, libcst, lazy-object-proxy, jinja2, itsdangerous, httptools, h11, gunicorn, grpcio, fsspec, dnspython, colorlog, blinker, attrs, asgiref, argcomplete, annotated-types, a2wsgi, watchfiles, uvicorn, universal-pathlib, typing-inspection, svcs, starlette, sqlalchemy-utils, sqlalchemy-jsonfield, pydantic-core, pendulum, opentelemetry-proto, methodtools, markdown-it-py, linkify-it-py, httpcore, googleapis-common-protos, flask, email-validator, deprecated, croniter, alembic, aiosqlite, aiologic, rich, pydantic, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, httpx, typer, rich-toolkit, rich-argparse, retryhttp, opentelemetry-semantic-conventions, fastapi, opentelemetry-sdk, fastapi-cli, cadwyn, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-exporter-otlp, apache-airflow-providers-common-compat, apache-airflow-providers-standard, apache-airflow-providers-smtp, apache-airflow-providers-common-sql, apache-airflow-providers-common-io, apache-airflow-task-sdk, apache-airflow-core, apache-airflow
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.8.0
#     Uninstalling typing_extensions-4.8.0:
#       Successfully uninstalled typing_extensions-4.8.0
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.22
#     Uninstalling SQLAlchemy-2.0.22:
#       Successfully uninstalled SQLAlchemy-2.0.22
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.8.0
#     Uninstalling PyJWT-2.8.0:
#       Successfully uninstalled PyJWT-2.8.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.24.3
#     Uninstalling protobuf-4.24.3:
#       Successfully uninstalled protobuf-4.24.3
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 1.3.0
#     Uninstalling pluggy-1.3.0:
#       Successfully uninstalled pluggy-1.3.0
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.2
#     Uninstalling Jinja2-3.1.2:
#       Successfully uninstalled Jinja2-3.1.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.9.2
#     Uninstalling fsspec-2023.9.2:
#       Successfully uninstalled fsspec-2023.9.2
#   Attempting uninstall: blinker
#     Found existing installation: blinker 1.6.3
#     Uninstalling blinker-1.6.3:
#       Successfully uninstalled blinker-1.6.3
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
#   Attempting uninstall: alembic
#     Found existing installation: alembic 1.12.0
#     Uninstalling alembic-1.12.0:
#       Successfully uninstalled alembic-1.12.0
# Successfully installed a2wsgi-1.10.8 aiologic-0.14.0 aiosqlite-0.21.0 alembic-1.16.1 annotated-types-0.7.0 apache-airflow-3.0.1 apache-airflow-core-3.0.1 apache-airflow-providers-common-compat-1.7.0 apache-airflow-providers-common-io-1.6.0 apache-airflow-providers-common-sql-1.27.1 apache-airflow-providers-smtp-2.1.0 apache-airflow-providers-standard-1.2.0 apache-airflow-task-sdk-1.0.1 argcomplete-3.6.2 asgiref-3.8.1 attrs-25.3.0 blinker-1.9.0 cadwyn-5.3.3 colorlog-6.9.0 cron-descriptor-1.4.5 croniter-6.0.0 deprecated-1.2.18 dnspython-2.7.0 email-validator-2.2.0 fastapi-0.115.12 fastapi-cli-0.0.7 flask-3.1.1 fsspec-2025.5.1 googleapis-common-protos-1.70.0 grpcio-1.71.0 gunicorn-23.0.0 h11-0.16.0 httpcore-1.0.9 httptools-0.6.4 httpx-0.28.1 itsdangerous-2.2.0 jinja2-3.1.6 lazy-object-proxy-1.11.0 libcst-1.8.0 linkify-it-py-2.0.3 lockfile-0.12.2 markdown-it-py-3.0.0 mdurl-0.1.2 methodtools-0.4.7 more-itertools-10.7.0 msgspec-0.19.0 opentelemetry-api-1.33.1 opentelemetry-exporter-otlp-1.33.1 opentelemetry-exporter-otlp-proto-common-1.33.1 opentelemetry-exporter-otlp-proto-grpc-1.33.1 opentelemetry-exporter-otlp-proto-http-1.33.1 opentelemetry-proto-1.33.1 opentelemetry-sdk-1.33.1 opentelemetry-semantic-conventions-0.54b1 pathspec-0.12.1 pendulum-3.1.0 pluggy-1.6.0 protobuf-5.29.5 psutil-7.0.0 pydantic-2.11.5 pydantic-core-2.33.2 pyjwt-2.10.1 python-daemon-3.1.2 python-dotenv-1.1.0 python-multipart-0.0.20 python-slugify-8.0.4 retryhttp-1.3.3 rich-14.0.0 rich-argparse-1.7.1 rich-toolkit-0.14.7 setproctitle-1.3.6 shellingham-1.5.4 sqlalchemy-1.4.54 sqlalchemy-jsonfield-1.0.2 sqlalchemy-utils-0.41.2 sqlparse-0.5.3 starlette-0.46.2 structlog-25.3.0 svcs-25.1.0 tabulate-0.9.0 tenacity-9.1.2 termcolor-3.1.0 text-unidecode-1.3 typer-0.16.0 types-requests-2.32.0.20250515 typing-inspection-0.4.1 typing_extensions-4.13.2 uc-micro-py-1.0.3 universal-pathlib-0.2.6 uuid6-2024.7.10 uvicorn-0.34.2 uvloop-0.21.0 watchfiles-1.0.5 websockets-15.0.1 werkzeug-3.1.3 wirerope-1.0.0 wrapt-1.17.2

# %% [markdown]
# ## Concepts
# ### DAG (Directed Acyclic Graph)
#
# A Directed Acyclic Graph (DAG) is a collection of tasks that are organized in a way that reflects their dependencies. In Airflow, DAGs define workflows where tasks must be executed in a specified sequence without any cyclic dependencies (loops). Each DAG has a start date, a schedule interval, and a set of tasks connected by dependencies.
#
# Key characteristics of DAGs:
#
#     - Directed: Tasks execute in a specific order.
#
#     - Acyclic: No task can depend on a downstream task that eventually depends on itself, preventing infinite loops.
#
#     - Graph: A network structure that allows for complex task dependencies.
#
# Example DAG visualization:
#
# ### Tasks and Operators
#
# Tasks are the fundamental building blocks of a DAG. Airflow provides predefined Operators for various tasks, such as:
#
#     - `PythonOperator` – Runs Python functions
#
#     - `BashOperator` – Executes shell commands
#
#     - `PostgresOperator` – Runs SQL queries on a Postgres database
#
#     - `SFTPOperator` – Transfers files via SFTP

# %% [markdown]
# ## A Simple DAGs example
# #### 0.Import required packages

# %%
from airflow import DAG
from airflow.operators.python import PythonOperator, BranchPythonOperator
from airflow.operators.empty import EmptyOperator
import pendulum
import random
# Out:
# /tmp/ipykernel_391/2529059098.py:2 DeprecationWarning: The `airflow.operators.python.PythonOperator` class is deprecated. Please use `'airflow.providers.standard.operators.python.PythonOperator'`.
# /tmp/ipykernel_391/2529059098.py:2 DeprecationWarning: The `airflow.operators.python.BranchPythonOperator` class is deprecated. Please use `'airflow.providers.standard.operators.python.BranchPythonOperator'`.
# /tmp/ipykernel_391/2529059098.py:3 DeprecationWarning: The `airflow.operators.empty.EmptyOperator` class is deprecated. Please use `'airflow.providers.standard.operators.empty.EmptyOperator'`.

# %% [markdown]
# #### 1.Define the workflow schedule frequency
# cheduling: Airflow supports cron-like scheduling using `schedule_interval` (e.g., `@daily`, `@hourly`, `0 12 * * *`).

# %%
WORKFLOW_SCHEDULE = "@hourly"

# %% [markdown]
# #### 2.Default arguments dictionary for the DAG execution

# %%
# Default arguments dictionary for the DAG execution
default_args = {
    'owner': 'beam-gutstein',  # Owner of the DAG
    'depends_on_past': False,  # Ensures tasks do not depend on past runs
    'start_date': pendulum.today('UTC').add(days=-1),  # DAG start date (yesterday)
    'retries': 1,  # Number of retry attempts upon failure
}

# %% [markdown]
# #### 3.Task Definition

# %%
# Task 1: Generates a success/failure outcome randomly
def task1_func(**kwargs):
    """
    Simulates a task that randomly determines success or failure.
    Output:
        - 'success' (50% probability)
        - 'failure' (50% probability)
    """
    print('Running task 1')
    value = 'success' if random.random() < 0.5 else 'failure'
    print(f'Task 1 output: {value}')
    return {'status': value}

# Task 2: Generates a random integer between 0 and 10
def task2_func(**kwargs):
    """
    Simulates a task that generates a random integer in the range [0, 10].
    Output:
        - Random integer (0-10)
    """
    print('Running task 2')
    value = random.randint(0, 10)
    print(f'Task 2 output: {value}')
    return {'value': value}

# Task 3: Generates two random integers between 0 and 10
def task3_func(**kwargs):
    """
    Simulates a task that generates two random integers in the range [0, 10].
    Output:
        - Two random integers (0-10)
    """
    print('Running task 3')
    value_one = random.randint(0, 10)
    value_two = random.randint(0, 10)
    print(f'Task 3 output: {value_one} {value_two}')
    return {'value1': value_one, 'value2': value_two}

# Task 4: Aggregates results from Task 1, Task 2, and Task 3
def task4_func(**kwargs):
    """
    Collects results from task1, task2, and task3 using XCom.
    Decides whether task5 should be executed based on:
        - If task3's first value is greater than the second value
        - If task1 returned 'success'
    Output:
        - "do-task5" if conditions are met, else empty string
    """
    print('Running task 4')
    ti = kwargs['ti']
    task1_return_value = ti.xcom_pull(task_ids='task1')
    task2_return_value = ti.xcom_pull(task_ids='task2')
    task3_return_value = ti.xcom_pull(task_ids='task3')
    
    print("Task 1 returned: ", task1_return_value)
    print("Task 2 returned: ", task2_return_value)
    print("Task 3 returned: ", task3_return_value)

    return_value = ""
    if task3_return_value['value1'] > task3_return_value['value2'] and task1_return_value['status'] == "success":
        return_value = "do-task5"
    
    return return_value

# Branching decision function
def decide_which_path(**kwargs):
    """
    Determines the next task to execute based on task4's output.
    Output:
        - 'task5' if task4 returns "do-task5"
        - 'dummy_task' otherwise
    """
    ti = kwargs['ti']
    task4_return_value = ti.xcom_pull(task_ids='task4')
    if task4_return_value == "do-task5":
        return 'task5'
    else:
        return 'dummy_task'

# Task 5: Final task execution
def task5_func(**kwargs):
    """
    Executes task5 if the branching condition is met.
    Output:
        - A dictionary indicating task completion
    """
    print('Running task 5')
    return {'task': 'task5', 'status': 'completed'}

# %% [markdown]
# #### 4.Initiate the DAG

# %%
dag = DAG(
    'example_dag',  # Name of the DAG
    default_args=default_args,
    description='An example DAG with dependencies',
    schedule=WORKFLOW_SCHEDULE,  # Schedule interval for DAG execution
    tags=["de300"]  # DAG tagging for categorization
)

# %% [markdown]
# #### 5.Define the tasks

# %%
# Task 1: Generates success/failure
task1 = PythonOperator(
    task_id='task1',
    python_callable=task1_func,
    dag=dag,
)

# Task 2: Generates a random integer
task2 = PythonOperator(
    task_id='task2',
    python_callable=task2_func,
    dag=dag,
)

# Task 3: Generates two random integers
task3 = PythonOperator(
    task_id='task3',
    python_callable=task3_func,
    dag=dag,
)

# Task 4: Aggregates task results and makes a decision
task4 = PythonOperator(
    task_id='task4',
    python_callable=task4_func,
    dag=dag,
)

# Branching task: Determines execution path based on task4's output
decide = BranchPythonOperator(
    task_id='branch_task',
    python_callable=decide_which_path,
    dag=dag,
)

# Task 5: Final task if the condition is met
task5 = PythonOperator(
    task_id='task5',
    python_callable=task5_func,
    dag=dag,
)

# Dummy task: Acts as an alternative path
dummy_task = EmptyOperator(
    task_id='dummy_task',
    dag=dag,
)

# %% [markdown]
# #### 6.Define the dependencies among tasks

# %%
[task1, task2, task3] >> task4 >> decide  # Task1, Task2, Task3 -> Task4 -> Decision

decide >> task5  # If condition met, execute Task5
decide >> dummy_task  # If condition not met, execute Dummy Task
# Out:
# <Task(EmptyOperator): dummy_task>

# %% [markdown]
# ### Best Practices
#
# 1. Parameterize workflows: Use Airflow variables and templates.
#
# 2. Use task dependencies: Define dependencies using `>>` and `<<`.

# %% [markdown]
# ## 0. Reads parameters from a TOML configuration file (optional)
# ```{python}
# def read_config() -> dict:
#     path = pathlib.Path(CONFIG_FILE)
#     with path.open(mode="rb") as param_file:
#         params = tomli.load(param_file)
#     return params
# ```

# %% [markdown]
# ## 1. DAG Definition and Configuration
#     - `dag_id`: Unique identifier for the DAG.
#     - `default_args`: Dictionary with default parameters for tasks.
#     - `schedule_interval`: Defines how often the DAG runs.
#     - `start_date`: Determines when the DAG starts running.
#     - `tags`: Helps categorize DAGs in the UI.
#
# ```python
# from airflow import DAG
# import pendulum
#
# default_args = {
#     'owner': 'user',
#     'depends_on_past': False,
#     'start_date': pendulum.today('UTC').add(days=-1),
#     'retries': 1,
# }
#
# dag = DAG(
#     'example_dag',
#     default_args=default_args,
#     description='A simple DAG example',
#     schedule_interval="@daily",
#     tags=['example']
# )
# ```
#
# ## 2. Task Definition
# ### PythonOperator
# Usage: Executes a Python function within a DAG.
# ```python
# from airflow.operators.python import PythonOperator
#
# def my_function(**kwargs):
#     print("Hello from PythonOperator")
#
# task = PythonOperator(
#     task_id='print_hello',
#     python_callable=my_function,
#     dag=dag
# )
# ```
# ### BashOperator
# ```python
# from airflow.operators.bash import BashOperator
#
# task = BashOperator(
#     task_id='print_date',
#     bash_command='date',
#     dag=dag
# )
# ```
# ### EmptyOperator
# ```python
# from airflow.operators.empty import EmptyOperator
#
# start = EmptyOperator(task_id='start', dag=dag)
# end = EmptyOperator(task_id='end', dag=dag)
# ```
#
# ## 3. Task Dependencies
# ```python
# task1 >> task2  # task1 runs before task2
# task3 << task2  # task3 runs after task2
#
# [task1, task2] >> task3  # Both task1 and task2 must complete before task3
# ```
#
# ## 4. XCom for Data Passing Between Tasks
# ### Push Data
# ```python
# def push_data(**kwargs):
#     ti = kwargs['ti']
#     ti.xcom_push(key='my_key', value=42)
# ```
# ### Pull Data
# ```python
# def pull_data(**kwargs):
#     ti = kwargs['ti']
#     value = ti.xcom_pull(task_ids='push_task', key='my_key')
#     print(f"Received value: {value}")
# ```
#
# ## 5. Branching Logic
# ```python
# from airflow.operators.python import BranchPythonOperator
#
# def choose_branch(**kwargs):
#     return 'task_A' if random.random() < 0.5 else 'task_B'
#
# branch_task = BranchPythonOperator(
#     task_id='branching',
#     python_callable=choose_branch,
#     dag=dag
# )
# ```
#
# ## 6. Sensors for External Triggers
# ### TimeSensor
# ```python
# from airflow.sensors.time_sensor import TimeSensor
#
# wait_for_time = TimeSensor(
#     task_id='wait_until_10am',
#     target_time='10:00:00',
#     dag=dag
# )
# ```
# ### FileSensor
# ```python
# from airflow.sensors.filesystem import FileSensor
#
# wait_for_file = FileSensor(
#     task_id='wait_for_file',
#     filepath='/path/to/file.txt',
#     poke_interval=60,
#     timeout=600,
#     dag=dag
# )
# ```
#
# ## 7. Triggering Other DAGs
# ```python
# from airflow.operators.trigger_dagrun import TriggerDagRunOperator
#
# trigger = TriggerDagRunOperator(
#     task_id='trigger_other_dag',
#     trigger_dag_id='other_dag',
#     dag=dag
# )
# ```
#
# ## 8. Dynamic Task Generation
# ```python
# task_list = []
# for i in range(3):
#     task = PythonOperator(
#         task_id=f'task_{i}',
#         python_callable=lambda: print(f"Task {i}"),
#         dag=dag
#     )
#     task_list.append(task)
#
# task_list[0] >> task_list[1] >> task_list[2]
# ```
#
# ## 9. Task Failure Handling
# ```python
# from datetime import timedelta
#
# def failure_callback(context):
#     print(f"Task {context['task_instance'].task_id} failed")
#
# task = PythonOperator(
#     task_id='task_with_failure_callback',
#     python_callable=my_function,
#     on_failure_callback=failure_callback,
#     retries=3,
#     retry_delay=timedelta(minutes=5),
#     dag=dag
# )
# ```
#
# ## 10. Parallel Task Execution
# ```python
# parallel_task1 = PythonOperator(task_id='parallel_1', python_callable=my_function, dag=dag)
# parallel_task2 = PythonOperator(task_id='parallel_2', python_callable=my_function, dag=dag)
#
# start >> [parallel_task1, parallel_task2] >> end
# ```
